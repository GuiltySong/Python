# %%
import pandas as pd

#df = pd.read_csv('Pokemon.txt', delimiter = '\t')
df = pd.read_csv('Pokemon.csv')

df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
## Read Headers
df.columns

## Read each Column
df[['Name', 'Type 1', 'HP']]

## Read each Rows
df.iloc[1:4]

#for index, row in df.iterrows():
#    print(index, row['Name'])

df.loc[df['Type 1'] == "Grass"]

## Read a specific location (r,c)
df.iloc[2,1]

## Sort Values
df.sort_values('#', ascending=False)
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
# 'Venusaur'

# %%
# df['Total'] = df['HP'] + df['Attack'] + df['Sp. Atk'] + df['Sp. Def'] + df['Defense'] + df['Speed']

# df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)

cols = list(df.columns.values)

df = df[cols[0:4] + [cols[-1]] + cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Generation  Legendary   Total  HP  \
# 0  1              Bulbasaur  Grass  Poison           1      False   799.0  45
# 1  2                Ivysaur  Grass  Poison           1      False  1015.0  60
# 2  3               Venusaur  Grass  Poison           1      False  1315.0  80
# 3  3  VenusaurMega Venusaur  Grass  Poison           1      False  1595.0  80
# 4  4             Charmander   Fire     NaN           1      False   747.0  39
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80
# 4      52       43       60       50     65

# %%
#df.to_csv('modified.csv', index=False)
#df.to_excel('modified.xlsx', index=False)
df.to_csv('modified.txt', index=False, sep='\t')

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
# Out:
#        #                     Name Type 1    Type 2  Generation  Legendary  \
# 0      1                Bulbasaur  Grass    Poison           1      False
# 1      2                  Ivysaur  Grass    Poison           1      False
# 2      3                 Venusaur  Grass    Poison           1      False
# 3      3    VenusaurMega Venusaur  Grass    Poison           1      False
# 16    13                   Weedle    Bug    Poison           1      False
# 17    14                   Kakuna    Bug    Poison           1      False
# 18    15                 Beedrill    Bug    Poison           1      False
# 19    15    BeedrillMega Beedrill    Bug    Poison           1      False
# 48    43                   Oddish  Grass    Poison           1      False
# 49    44                    Gloom  Grass    Poison           1      False
# 50    45                Vileplume  Grass    Poison           1      False
# 53    48                  Venonat    Bug    Poison           1      False
# 54    49                 Venomoth    Bug    Poison           1      False
# 75    69               Bellsprout  Grass    Poison           1      False
# 76    70               Weepinbell  Grass    Poison           1      False
# 77    71               Victreebel  Grass    Poison           1      False
# 78    72                Tentacool  Water    Poison           1      False
# 79    73               Tentacruel  Water    Poison           1      False
# 99    92                   Gastly  Ghost    Poison           1      False
# 100   93                  Haunter  Ghost    Poison           1      False
# 101   94                   Gengar  Ghost    Poison           1      False
# 102   94        GengarMega Gengar  Ghost    Poison           1      False
# 110  102                Exeggcute  Grass   Psychic           1      False
# 111  103                Exeggutor  Grass   Psychic           1      False
# 122  114                  Tangela  Grass       NaN           1      False
# 166  152                Chikorita  Grass       NaN           2      False
# 167  153                  Bayleef  Grass       NaN           2      False
# 168  154                 Meganium  Grass       NaN           2      False
# 181  167                 Spinarak    Bug    Poison           2      False
# 182  168                  Ariados    Bug    Poison           2      False
# ..   ...                      ...    ...       ...         ...        ...
# 509  459                   Snover  Grass       Ice           4      False
# 510  460                Abomasnow  Grass       Ice           4      False
# 511  460  AbomasnowMega Abomasnow  Grass       Ice           4      False
# 516  465                Tangrowth  Grass       NaN           4      False
# 521  470                  Leafeon  Grass       NaN           4      False
# 550  492        ShayminLand Forme  Grass       NaN           4       True
# 551  492         ShayminSky Forme  Grass    Flying           4       True
# 554  495                    Snivy  Grass       NaN           5      False
# 555  496                  Servine  Grass       NaN           5      False
# 556  497                Serperior  Grass       NaN           5      False
# 570  511                  Pansage  Grass       NaN           5      False
# 571  512                 Simisage  Grass       NaN           5      False
# 603  543                 Venipede    Bug    Poison           5      False
# 604  544               Whirlipede    Bug    Poison           5      False
# 605  545                Scolipede    Bug    Poison           5      False
# 606  546                 Cottonee  Grass     Fairy           5      False
# 607  547               Whimsicott  Grass     Fairy           5      False
# 608  548                  Petilil  Grass       NaN           5      False
# 609  549                Lilligant  Grass       NaN           5      False
# 617  556                 Maractus  Grass       NaN           5      False
# 651  590                  Foongus  Grass    Poison           5      False
# 652  591                Amoonguss  Grass    Poison           5      False
# 658  597                Ferroseed  Grass     Steel           5      False
# 659  598               Ferrothorn  Grass     Steel           5      False
# 701  640                 Virizion  Grass  Fighting           5       True
# 718  650                  Chespin  Grass       NaN           6      False
# 719  651                Quilladin  Grass       NaN           6      False
# 720  652               Chesnaught  Grass  Fighting           6      False
# 740  672                   Skiddo  Grass       NaN           6      False
# 741  673                   Gogoat  Grass       NaN           6      False
#
#       Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0     799.0   45      49       49       65       65     45
# 1    1015.0   60      62       63       80       80     60
# 2    1315.0   80      82       83      100      100     80
# 3    1595.0   80     100      123      122      120     80
# 16    465.0   40      35       30       20       20     50
# 17    520.0   45      25       50       25       25     35
# 18    955.0   65      90       40       45       80     75
# 19   1115.0   65     150       40       15       80    145
# 48    835.0   45      50       55       75       65     30
# 49   1030.0   60      65       70       85       75     40
# 50   1280.0   75      80       85      110       90     50
# 53    770.0   60      55       50       40       55     45
# 54   1095.0   70      65       60       90       75     90
# 75    790.0   50      75       35       70       30     40
# 76   1015.0   65      90       50       85       45     55
# 77   1260.0   80     105       65      100       70     70
# 78    765.0   40      40       35       50      100     70
# 79   1225.0   80      70       65       80      120    100
# 99    735.0   30      35       30      100       35     80
# 100   970.0   45      50       45      115       55     95
# 101  1205.0   60      65       60      130       75    110
# 102  1445.0   60      65       80      170       95    130
# 110   850.0   60      40       80       60       45     40
# 111  1385.0   95      95       85      125       65     55
# 122  1145.0   65      55      115      100       40     60
# 166   799.0   45      49       65       49       65     45
# 167  1015.0   60      62       80       63       80     60
# 168  1315.0   80      82      100       83      100     80
# 181   650.0   40      60       40       40       40     30
# 182  1030.0   70      90       70       60       60     40
# ..      ...  ...     ...      ...      ...      ...    ...
# 509   862.0   60      62       50       62       60     40
# 510  1277.0   90      92       75       92       85     60
# 511  1617.0   90     132      105      132      105     30
# 516  1455.0  100     100      125      110       50     50
# 521  1320.0   65     110      130       60       65     95
# 550  1501.0  100     100      100      100      100    100
# 551  1472.0  100     103       75      120       75    127
# 554   743.0   45      45       55       45       55     63
# 555   998.0   60      60       75       60       75     83
# 556  1263.0   75      75       95       75       95    113
# 570   772.0   50      53       48       53       48     64
# 571  1229.0   75      98       63       98       63    101
# 603   627.0   30      45       59       30       39     57
# 604   907.0   40      55       99       40       79     47
# 605  1162.0   60     100       89       55       69    112
# 606   658.0   40      27       60       37       50     66
# 607  1133.0   60      67       85       77       75    116
# 608   730.0   45      35       50       70       50     30
# 609  1185.0   70      60       75      110       75     90
# 617  1196.0   75      86       67      106       67     60
# 651   797.0   69      55       45       55       55     15
# 652  1252.0  114      85       70       85       80     30
# 658   809.0   44      50       91       24       86     10
# 659  1311.0   74      94      131       54      116     20
# 701  1396.0   91      90       72       90      129    108
# 718   818.0   56      61       65       48       45     38
# 719  1043.0   61      78       95       56       58     57
# 720  1387.0   88     107      122       74       75     64
# 740   889.0   66      65       48       62       57     52
# 741  1376.0  123     100       62       97       81     68
#
# [89 rows x 13 columns]

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.reset_index(drop=True, inplace=True)

new_df
# Out:
#      #                   Name Type 1  Type 2  Generation  Legendary   Total  \
# 0    3               Venusaur  Grass  Poison           1      False  1315.0
# 1    3  VenusaurMega Venusaur  Grass  Poison           1      False  1595.0
# 2   45              Vileplume  Grass  Poison           1      False  1280.0
# 3   71             Victreebel  Grass  Poison           1      False  1260.0
# 4  591              Amoonguss  Grass  Poison           5      False  1252.0
#
#     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0   80      82       83      100      100     80
# 1   80     100      123      122      120     80
# 2   75      80       85      110       90     50
# 3   80     105       65      100       70     70
# 4  114      85       70       85       80     30

# %%
#df.loc[df['Name'].str.contains('Mega')]
#df.loc[~df['Name'].str.contains('Mega')]
import re

#df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex = True)]
df.loc[df['Name'].str.contains('pi[a-z]*', flags=re.I, regex = True)]
# Out:
#        #                     Name    Type 1    Type 2  Generation  Legendary  \
# 13    10                 Caterpie       Bug       NaN           1      False
# 20    16                   Pidgey    Normal    Flying           1      False
# 21    17                Pidgeotto    Normal    Flying           1      False
# 22    18                  Pidgeot    Normal    Flying           1      False
# 23    18      PidgeotMega Pidgeot    Normal    Flying           1      False
# 30    25                  Pikachu  Electric       NaN           1      False
# 42    37                   Vulpix      Fire       NaN           1      False
# 76    70               Weepinbell     Grass    Poison           1      False
# 84    78                 Rapidash      Fire       NaN           1      False
# 136  127                   Pinsir       Bug       NaN           1      False
# 137  127        PinsirMega Pinsir       Bug    Flying           1      False
# 181  167                 Spinarak       Bug    Poison           2      False
# 186  172                    Pichu  Electric       NaN           2      False
# 189  175                   Togepi     Fairy       NaN           2      False
# 202  187                   Hoppip     Grass    Flying           2      False
# 219  204                   Pineco       Bug       NaN           2      False
# 239  221                Piloswine       Ice    Ground           2      False
# 266  247                  Pupitar      Rock    Ground           2      False
# 345  316                   Gulpin    Poison       NaN           3      False
# 357  326                  Grumpig   Psychic       NaN           3      False
# 358  327                   Spinda    Normal       NaN           3      False
# 359  328                 Trapinch    Ground       NaN           3      False
# 390  357                  Tropius     Grass    Flying           3      False
# 438  393                   Piplup     Water       NaN           4      False
# 463  416                Vespiquen       Bug    Flying           4      False
# 488  440                  Happiny    Normal       NaN           4      False
# 490  442                Spiritomb     Ghost      Dark           4      False
# 501  451                  Skorupi    Poison       Bug           4      False
# 502  452                  Drapion    Poison      Dark           4      False
# 557  498                    Tepig      Fire       NaN           5      False
# 558  499                  Pignite      Fire  Fighting           5      False
# 578  519                   Pidove    Normal    Flying           5      False
# 596  536                Palpitoad     Water    Ground           5      False
# 716  648  MeloettaPirouette Forme    Normal  Fighting           5      False
# 718  650                  Chespin     Grass       NaN           6      False
#
#       Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 13    475.0   45      30       35       20       20     45
# 20    606.0   40      45       40       35       35     56
# 21    855.0   63      60       55       50       50     71
# 22   1165.0   83      80       75       70       70    101
# 23   1415.0   83      80       80      135       80    121
# 30    730.0   35      55       40       50       50     90
# 42    702.0   38      41       40       50       65     65
# 76   1015.0   65      90       50       85       45     55
# 84   1210.0   65     100       70       80       80    105
# 136  1260.0   65     125      100       55       70     85
# 137  1500.0   65     155      120       65       90    105
# 181   650.0   40      60       40       40       40     30
# 186   460.0   20      40       15       35       35     60
# 189   630.0   35      20       65       40       65     20
# 202   595.0   35      35       40       35       55     50
# 219   805.0   50      65       90       35       35     15
# 239  1190.0  100     100       80       60       60     50
# 266  1058.0   70      84       70       65       70     51
# 345   773.0   70      43       53       43       53     40
# 357  1140.0   80      45       65       90      110     80
# 358   900.0   60      60       60       60       60     60
# 359   805.0   45     100       45       45       45     10
# 390  1191.0   99      68       83       72       87     51
# 438   806.0   53      51       53       61       56     40
# 463  1240.0   70      80      102       80      102     40
# 488   535.0  100       5        5       15       65     30
# 490  1277.0   50      92      108       92      108     35
# 501   805.0   40      50       90       30       55     65
# 502  1235.0   70      90      110       60       75     95
# 557   789.0   65      63       45       45       45     45
# 558  1089.0   90      93       55       70       55     55
# 578   676.0   50      55       50       36       30     43
# 596   959.0   75      65       55       65       55     69
# 716  1467.0  100     128       90       77       77    128
# 718   818.0   56      61       65       48       45     38

# %%
#df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

df = pd.read_csv('modified.csv')

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)
# Out:
#                    #  Generation  Legendary        Total         HP  \
# Type 1
# Steel     442.851852    3.851852   0.148148  1272.111111  65.222222
# Rock      392.727273    3.454545   0.090909  1174.045455  65.363636
# Dragon    474.375000    3.875000   0.375000  1397.062500  83.312500
# Ground    356.281250    3.156250   0.125000  1122.062500  73.781250
# Ghost     486.500000    4.187500   0.062500  1113.593750  64.437500
# Water     303.089286    2.857143   0.035714  1088.955357  72.062500
# Ice       423.541667    3.541667   0.083333  1097.250000  72.000000
# Grass     344.871429    3.357143   0.042857  1069.185714  67.271429
# Bug       334.492754    3.217391   0.000000   948.623188  56.884058
# Dark      461.354839    4.032258   0.064516  1115.451613  66.806452
# Poison    251.785714    2.535714   0.000000  1005.892857  67.250000
# Fire      327.403846    3.211538   0.096154  1153.230769  69.903846
# Psychic   380.807018    3.385965   0.245614  1178.824561  70.631579
# Electric  363.500000    3.272727   0.090909  1087.613636  59.795455
# Flying    677.750000    5.500000   0.500000  1178.000000  70.750000
# Fighting  363.851852    3.370370   0.000000  1052.481481  69.851852
# Fairy     449.529412    4.117647   0.058824  1057.705882  74.117647
# Normal    319.173469    3.051020   0.020408   998.244898  77.275510
#
#               Attack     Defense    Sp. Atk    Sp. Def       Speed
# Type 1
# Steel      92.703704  126.370370  67.518519  80.629630   55.259259
# Rock       92.863636  100.795455  63.340909  75.477273   55.909091
# Dragon    112.125000   86.375000  96.843750  88.843750   83.031250
# Ground     95.750000   84.843750  56.468750  62.750000   63.906250
# Ghost      73.781250   81.187500  79.343750  76.468750   64.343750
# Water      74.151786   72.946429  74.812500  70.517857   65.964286
# Ice        72.750000   71.416667  77.541667  76.291667   63.458333
# Grass      73.214286   70.800000  77.500000  70.428571   61.928571
# Bug        70.971014   70.724638  53.869565  64.797101   61.681159
# Dark       88.387097   70.225806  74.645161  69.516129   76.161290
# Poison     74.678571   68.821429  60.428571  64.392857   63.571429
# Fire       84.769231   67.769231  88.980769  72.211538   74.442308
# Psychic    71.456140   67.684211  98.403509  86.280702   81.491228
# Electric   69.090909   66.295455  90.022727  73.704545   84.500000
# Flying     78.750000   66.250000  94.250000  72.500000  102.500000
# Fighting   96.777778   65.925926  53.111111  64.703704   66.074074
# Fairy      61.529412   65.705882  78.529412  84.705882   48.588235
# Normal     73.469388   59.846939  55.816327  63.724490   71.551020

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #  Generation  Legendary     Total    HP  Attack  Defense  \
# Type 1
# Bug       23080         222        0.0   65455.0  3925    4897     4880
# Dark      14302         125        2.0   34579.0  2071    2740     2177
# Dragon    15180         124       12.0   44706.0  2666    3588     2764
# Electric  15994         144        4.0   47855.0  2631    3040     2917
# Fairy      7642          70        1.0   17981.0  1260    1046     1117
# Fighting   9824          91        0.0   28417.0  1886    2613     1780
# Fire      17025         167        5.0   59968.0  3635    4408     3524
# Flying     2711          22        2.0    4712.0   283     315      265
# Ghost     15568         134        2.0   35635.0  2062    2361     2598
# Grass     24141         235        3.0   74843.0  4709    5125     4956
# Ground    11401         101        4.0   35906.0  2361    3064     2715
# Ice       10165          85        2.0   26334.0  1728    1746     1714
# Normal    31279         299        2.0   97828.0  7573    7200     5865
# Poison     7050          71        0.0   28165.0  1883    2091     1927
# Psychic   21706         193       14.0   67193.0  4026    4073     3858
# Rock      17280         152        4.0   51658.0  2876    4086     4435
# Steel     11957         104        4.0   34347.0  1761    2503     3412
# Water     33946         320        4.0  121963.0  8071    8305     8170
#
#           Sp. Atk  Sp. Def  Speed
# Type 1
# Bug          3717     4471   4256
# Dark         2314     2155   2361
# Dragon       3099     2843   2657
# Electric     3961     3243   3718
# Fairy        1335     1440    826
# Fighting     1434     1747   1784
# Fire         4627     3755   3871
# Flying        377      290    410
# Ghost        2539     2447   2059
# Grass        5425     4930   4335
# Ground       1807     2008   2045
# Ice          1861     1831   1523
# Normal       5470     6245   7012
# Poison       1692     1803   1780
# Psychic      5609     4918   4645
# Rock         2787     3321   2460
# Steel        1823     2177   1492
# Water        8379     7898   7388

# %%
df['Count'] = 1
df.groupby(['Type 1']).count()['Count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Count, dtype: int64

# %% [markdown]
# # Work with Large Amount of Data

# %%
#new_df = pd.DataFrame(columns=df.columns)

#for df in pd.read_csv('modified.csv', chunksize=5):
#    results = df.groupby(['Type 1']).count()
    
#    new_df = pd.concat([new_df, results])
